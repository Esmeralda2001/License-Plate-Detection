# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext pycodestyle_magic
# %flake8_on --max_line_length 119

# %%
import Detection
import time
import os
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Loading the model

# %%
model, cfg = Detection.LoadModel("mask_rcnn_plate_cfg_vers2_00100.h5")
# Out:
# mask_rcnn_plate_cfg_vers2_00100.h5

# %% [markdown]
# # Measuring speed
# The following code is to measure the average speed of the detection model. The speed will vary based on your system's hardware.

# %%
path = r"C:/Users/midni/Desktop/School/INNO/opencv-anpr/license_plates/group3/"

# %%
average = []

counter = 0
files = os.listdir(path)

for pic in sorted(files):
    filename = os.fsdecode(pic)
    pic_path = path + filename
    start = time.time()
    plates = Detection.detect_and_return_plate(pic_path, model, cfg)
    average.append(time.time()-start)

# %%
print("Total speed:", sum(average)/len(average))
# Out:
# Total speed: 13.948296740248397

# %% [markdown]
# # Single detection

# %%
plates = Detection.detect_and_return_plate(path+"027.jpg", model, cfg, debug=True)
print(plates)
# Out:
# Confidence score: [0.99546814 0.97702676]
# [['XT-567-K', 'XT-567-L'], ['E-JC0LZL', 'E3C4LIJ', 'C-IC5LZL', 'E-IC4RZL', 'L1-Z1D1J', 'E-I4LZL']]
